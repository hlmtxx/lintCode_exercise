# %%
15//8

# %%
def quick_sort_standord(array,low,high):
    ''' realize from book "data struct" of author 严蔚敏
    '''
    if low < high:
        key_index = partion(array,low,high)
        quick_sort_standord(array,low,key_index-1)
        quick_sort_standord(array,key_index+1,high)

def partion(array,low,high):
    key = array[low]
    while low < high:
        while low < high and array[high] >= key: #右边找到第一个比key小的数
            high -= 1
        if low < high:
            array[low] = array[high]

        while low < high and array[low] <= key: #左边找到第一个比key大的数
            low += 1
        if low < high:
            array[high] = array[low]

    array[low] = key
    return low


if __name__ == '__main__':
    array2 = [9,3,2,1,4,4,6,7,0,5]

    print array2
    quick_sort_standord(array2,0,len(array2)-1)
    print array2
# Out:
# [9, 3, 2, 1, 4, 4, 6, 7, 0, 5]
# [0, 1, 2, 3, 4, 4, 5, 6, 7, 9]

# %%
def quick_sort_standord(array,low,high):
    ''' realize from book "data struct" of author 严蔚敏
    '''
    if low < high:
        key_index = partion(array,low,high)
        quick_sort_standord(array,low,key_index-1)
        quick_sort_standord(array,key_index+1,high)

def partion(array,low,high):
    key = array[high]
    while low < high:
        while low < high and array[low] <= key: #左边找到第一个比key大的数
            low += 1
            #print 'low',low
        if low < high:
            array[high] = array[low]
        while low < high and array[high] >= key: #右边找到第一个比key小的数
            high -= 1
            #print 'high',high
        if low < high:
            array[low] = array[high]



    
    array[low] = key
    print low
    print array
    return low


if __name__ == '__main__':
    array2 = [9,3,4,2,1,5,4,6,3,0,4]

    print array2
    quick_sort_standord(array2,0,len(array2)-1)
    print array2
# Out:
# [9, 3, 4, 2, 1, 5, 4, 6, 3, 0, 4]
# 7
# [0, 3, 4, 2, 1, 3, 4, 4, 6, 5, 9]
# 6
# [0, 3, 4, 2, 1, 3, 4, 4, 6, 5, 9]
# 4
# [0, 3, 1, 2, 3, 4, 4, 4, 6, 5, 9]
# 2
# [0, 1, 2, 3, 3, 4, 4, 4, 6, 5, 9]
# 1
# [0, 1, 2, 3, 3, 4, 4, 4, 6, 5, 9]
# 10
# [0, 1, 2, 3, 3, 4, 4, 4, 6, 5, 9]
# 8
# [0, 1, 2, 3, 3, 4, 4, 4, 5, 6, 9]
# [0, 1, 2, 3, 3, 4, 4, 4, 5, 6, 9]

# %%
def quick_sort_standord(array,low,high):
    ''' realize from book "data struct" of author 严蔚敏
    '''
    if low < high:
        new_high = partion(array,low,high)
        print array[low:new_high]
        quick_sort_standord(array,low,new_high)
        print array[new_high+1,high]
        quick_sort_standord(array,new_high+1,high)

def partion(array,low,high):
    
    key = array[(low+high)//2]
    print key
    while low <=high:
        while low <= high and array[low] < key: #左边找到第一个>=key的数
            low += 1
            print 'low',low
        
        while low <= high and array[high] > key: #右边找到第一个<=key的数
            high -= 1
            print 'high',high
        if low <= high:
            array[low],array[high] = array[high],array[low]
            low+=1
            high-=1
            


    #print 'final low',low,array[low]
    #array[low] = key
    return high


if __name__ == '__main__':
    array2 = [9,3,2,1,4,4,6,3,0,5]

    print array2
    quick_sort_standord(array2,0,len(array2)-1)
    print array2
# Out:
# [9, 3, 2, 1, 4, 4, 6, 3, 0, 5]
# 4
# high 8
# low 2
# low 3
# low 4
# high 5
# 2
# low 1
# high 3
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# 0
# high 0
# ...

# %%
5/2
# Out:
# 2

# %%
5//2
# Out:
# 2
